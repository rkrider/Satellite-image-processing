# %%
import rasterio
import rasterio
from rasterio.plot import show
fp = r'Geotif_image15082020.tif'
img = rasterio.open(fp)
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A008882_20181118T043524.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A009454_20181228T043927.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A009597_20190107T043708.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A009740_20190117T043639.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A010026_20190206T043539.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A010455_20190308T044054.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A011027_20190417T043607.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A014144_20180308T043336.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A014173_20191123T043720.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A015031_20200122T043710.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A018148_20181213T043713.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A024297_20200216T044210.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A023153_20191128T043629.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A024011_20200127T043231.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
fp = r'L1C_T45QYE_A024869_20200327T043941.tif'
img = rasterio.open(fp) 
show(img.read(3))

# %%
import rasterio as rs

# %%
dataset=rs.open('L1C_T45QYE_A024869_20200327T043941.tif')

# %%
print(dataset.count) #returns no. of bands
# Out:
# 3

# %%
print(dataset.height,dataset.width) #returns image resolution
# Out:
# 5490 5490

# %%
print(dataset.crs) #returns CRS
# Out:
# EPSG:32645
